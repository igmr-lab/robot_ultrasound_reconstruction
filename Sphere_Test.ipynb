# %%
from google.colab import drive
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm

# Import data from drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Image template for importing images
bscan_image_template = bscan_image_template = '/content/drive/MyDrive/dataset/2024_2025_RAUS_dataset_linear/20250209_phantom_1_linear/{}_bmode.npy'

plane_images = []

# Generate plane_images by importing B-scan images
for idx in tqdm(range(150), desc="Processing"):
    bscan_image_path = bscan_image_template.format(idx)
    bscan_image = np.load(bscan_image_path)

    if (bscan_image is None):
        raise FileNotFoundError(f"Image not found at path")

    plane_images.append(bscan_image)
# Out:
# Processing: 100%|██████████| 150/150 [00:36<00:00,  4.10it/s]

# %%
plane_images = np.array(plane_images)
plane_images.shape
# Out:
# (150, 1083, 371, 4)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rotate the slice 90 degrees counterclockwise
rotated_intensity = np.rot90(plane_images[:, 400:800, 186, :], k = -3)

plt.figure(figsize= (4 * 1.5, 4 * 3 * 400 / 1083))
plt.imshow(rotated_intensity, cmap='gray', origin='lower', aspect='auto')
# plt.colorbar(label="Intensity")
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rotate the slice 90 degrees counterclockwise
rotated_intensity = np.rot90(plane_images[75, 400:800, 70:300, :], k = -2)

plt.figure(figsize= (4 * 2.5 * 230 / 371, 4 * 3 * 400 / 1083))
plt.imshow(rotated_intensity, cmap='gray', origin='lower', aspect='auto')
# plt.colorbar(label="Intensity")
plt.axis('off')
plt.show()
